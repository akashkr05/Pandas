# %% [markdown]
# # csv read

# %%
import pandas as pd

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv")
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %%
import os  # check where current working directory is stored

# %%
print(os.getcwd())
# Out:
# C:\Users\kumar\pandas practical

# %% [markdown]
# # Parameters of pandas read_csv function

# %% [markdown]
# # Columns:- This will access all column name in file.

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv")
print(df)
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %% [markdown]
# # Columns:- this will access all columns name

# %%
df.columns
# Out:
# Index(['student id,class,study hr,sleeping hr,social media,mobile game ,percentage'], dtype='object')

# %% [markdown]
# # nrows():- this will access specific rows

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", nrows = 3)  # nrows = no.(jitne rows chahiye)
df
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", nrows = 1)  # nrows = no.(jitne rows chahiye)
df
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8

# %% [markdown]
# # usecols:- this will access specific columns and they always take in list of index

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", usecols = [1])  
df
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_20312\3024258782.py:1: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", usecols = [1])
# Empty DataFrame
# Columns: [student id,class,study hr,sleeping hr,social media,mobile game ,percentage]
# Index: []

# %% [markdown]
#  pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv")

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", usecols = [1,3,2])  
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", usecols = [1,3,2])
#       2 df
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# # Skiprows():- this will skip specific rows in file

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", skiprows = 5)  # starting ki 5 rows skip kar dega  
df
# Out:
#    1005,11,7,13,2,4,85
# 0  1003,10,5,15,5,2,98

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv")
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", skiprows = [3])  # agar list me index denge toh ye particular row ko hi skip krega
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1006,11,8,13,1,5,80
# 3                                1005,11,7,13,2,4,85
# 4                                1003,10,5,15,5,2,98

# %% [markdown]
# # index_col:- ye particular column ko index bna deta hai or isko list of index , ya name likhkar column ka print kar skte hai.

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", index_col = [3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", index_col = [3])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# # Header:- kisi bhi row ko heading banane ka kaam krta hai

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv")
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", header = 1)
# Out:
#     1004,11,6,14,3,3,8
# 0  1001,10,3,12,3,2,67
# 1  1002,10,4,12,4,3,68
# 2  1006,11,8,13,1,5,80
# 3  1005,11,7,13,2,4,85
# 4  1003,10,5,15,5,2,98

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", header = None)
# Out:
#                                                    0
# 0  student id,class,study hr,sleeping hr,social m...
# 1                                 1004,11,6,14,3,3,8
# 2                                1001,10,3,12,3,2,67
# 3                                1002,10,4,12,4,3,68
# 4                                1006,11,8,13,1,5,80
# 5                                1005,11,7,13,2,4,85
# 6                                1003,10,5,15,5,2,98

# %% [markdown]
# # prefix:-

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", header = None, prefix = 'data')
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_20312\3849231065.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", header = None, prefix = 'data')
#                                                data0
# 0  student id,class,study hr,sleeping hr,social m...
# 1                                 1004,11,6,14,3,3,8
# 2                                1001,10,3,12,3,2,67
# 3                                1002,10,4,12,4,3,68
# 4                                1006,11,8,13,1,5,80
# 5                                1005,11,7,13,2,4,85
# 6                                1003,10,5,15,5,2,98

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", header = None, prefix = 'Akash')
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_20312\2609704014.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", header = None, prefix = 'Akash')
#                                               Akash0
# 0  student id,class,study hr,sleeping hr,social m...
# 1                                 1004,11,6,14,3,3,8
# 2                                1001,10,3,12,3,2,67
# 3                                1002,10,4,12,4,3,68
# 4                                1006,11,8,13,1,5,80
# 5                                1005,11,7,13,2,4,85
# 6                                1003,10,5,15,5,2,98

# %% [markdown]
# # Names

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", names = ['a', 'b', 'c', 'd', 'e', 'f', 'g'])
# Out:
#                                                    a   b   c   d   e   f   g
# 0  student id,class,study hr,sleeping hr,social m... NaN NaN NaN NaN NaN NaN
# 1                                 1004,11,6,14,3,3,8 NaN NaN NaN NaN NaN NaN
# 2                                1001,10,3,12,3,2,67 NaN NaN NaN NaN NaN NaN
# 3                                1002,10,4,12,4,3,68 NaN NaN NaN NaN NaN NaN
# 4                                1006,11,8,13,1,5,80 NaN NaN NaN NaN NaN NaN
# 5                                1005,11,7,13,2,4,85 NaN NaN NaN NaN NaN NaN
# 6                                1003,10,5,15,5,2,98 NaN NaN NaN NaN NaN NaN

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", names = ['akash', 'vikas', 'prakash', 'rohit', 'sohit', 'mohit', 'rita'])
# Out:
#                                                akash  vikas  prakash  rohit  \
# 0  student id,class,study hr,sleeping hr,social m...    NaN      NaN    NaN
# 1                                 1004,11,6,14,3,3,8    NaN      NaN    NaN
# 2                                1001,10,3,12,3,2,67    NaN      NaN    NaN
# 3                                1002,10,4,12,4,3,68    NaN      NaN    NaN
# 4                                1006,11,8,13,1,5,80    NaN      NaN    NaN
# 5                                1005,11,7,13,2,4,85    NaN      NaN    NaN
# 6                                1003,10,5,15,5,2,98    NaN      NaN    NaN
#
#    sohit  mohit  rita
# 0    NaN    NaN   NaN
# 1    NaN    NaN   NaN
# 2    NaN    NaN   NaN
# 3    NaN    NaN   NaN
# 4    NaN    NaN   NaN
# 5    NaN    NaN   NaN
# 6    NaN    NaN   NaN

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv")
df
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %% [markdown]
# # head()

# %%
df.head()
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85

# %%
df.head(3)
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68

# %% [markdown]
# # tail()

# %%
df.tail()
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %%
df.tail(2)
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %% [markdown]
# # dtype{}

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", dtype = {'study hr' : 'float'})
df
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", dtype = {'mobile game' : 'float'})
df
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %% [markdown]
# # true_values()

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\machine learning csv.csv", true_values = ['yes'])
df
# Out:
#   student id,class,study hr,sleeping hr,social media,mobile game ,percentage
# 0                                 1004,11,6,14,3,3,8
# 1                                1001,10,3,12,3,2,67
# 2                                1002,10,4,12,4,3,68
# 3                                1006,11,8,13,1,5,80
# 4                                1005,11,7,13,2,4,85
# 5                                1003,10,5,15,5,2,98

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part 7.csv")
df
# Out:
#    student id class  study hr  sleeping hr  social media mobile game   \
# 0        1004   yes         6           14             3            3
# 1        1001   yes         3           12             3          yes
# 2        1002   yes         4           12             4           no
# 3        1006    no         8           13             1            5
# 4        1005   yes         7           13             2            4
# 5        1003    no         5           15             5            2
#
#    percentage
# 0           8
# 1          67
# 2          68
# 3          80
# 4          85
# 5          98

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part 7.csv", true_values = ['yes'])
df
# Out:
#    student id class  study hr  sleeping hr  social media mobile game   \
# 0        1004   yes         6           14             3            3
# 1        1001   yes         3           12             3          yes
# 2        1002   yes         4           12             4           no
# 3        1006    no         8           13             1            5
# 4        1005   yes         7           13             2            4
# 5        1003    no         5           15             5            2
#
#    percentage
# 0           8
# 1          67
# 2          68
# 3          80
# 4          85
# 5          98

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part 7.csv", true_values = ['yes'], false_values = ['no'])
df
# Out:
#    student id  class  study hr  sleeping hr  social media mobile game   \
# 0        1004   True         6           14             3            3
# 1        1001   True         3           12             3          yes
# 2        1002   True         4           12             4           no
# 3        1006  False         8           13             1            5
# 4        1005   True         7           13             2            4
# 5        1003  False         5           15             5            2
#
#    percentage
# 0           8
# 1          67
# 2          68
# 3          80
# 4          85
# 5          98

# %% [markdown]
# # Handling missing values in python

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part 7.csv")
# Out:
#    student id class  study hr  sleeping hr  social media mobile game   \
# 0        1004   yes         6           14             3            3
# 1        1001   yes         3           12             3          yes
# 2        1002   yes         4           12             4           no
# 3        1006    no         8           13             1            5
# 4        1005   yes         7           13             2            4
# 5        1003    no         5           15             5            2
#
#    percentage
# 0           8
# 1          67
# 2          68
# 3          80
# 4          85
# 5          98

# %% [markdown]
# # na_values()

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part 7.csv")
# Out:
#    student id class  study hr  sleeping hr  social media mobile game   \
# 0        1004   yes         6           14             3            3
# 1        1001   yes         3           12             3          yes
# 2        1002   yes         4           12             4           no
# 3        1006    no         8           13             1            5
# 4        1005   yes         7           13             2            4
# 5        1003    no         5           15             5            2
#
#    percentage
# 0           8
# 1          67
# 2          68
# 3          80
# 4          85
# 5          98
