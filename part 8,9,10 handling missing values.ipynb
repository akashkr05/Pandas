# %%
import pandas as pd

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv")
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_values = 'no values')
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas         NaN    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_values = ['no values', 'not available', 'non'])
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas         NaN    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %% [markdown]
# # use dictionary ---- ye specific column ki string ko convert krta hai NaN me

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_values = {'Name' : 'sohit', 'companies' : 'health'})
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash         NaN    40%   hema
# 3   4      NaN         NaN    46%  gehna
# 4   5   cheems         NaN    59%    NaN
# 5   6     yash         NaN    90%    NaN

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv")
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %% [markdown]
# # Keep default na = Boolean

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", keep_default_na = False)
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values
# 2   3  prakash      health    40%   hema
# 3   4    sohit                46%  gehna
# 4   5   cheems      health    59%
# 5   6     yash      health    90%

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", keep_default_na = True)
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %% [markdown]
# # na_filter = false

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_filter = False)
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values
# 2   3  prakash      health    40%   hema
# 3   4    sohit                46%  gehna
# 4   5   cheems      health    59%
# 5   6     yash      health    90%

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_filter = True)
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %% [markdown]
# # isnull()

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv")
df
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_values = 'not available')
df
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df.isnull()
# Out:
#       id   Name  companies  profit  Girls
# 0  False  False      False   False  False
# 1  False  False      False    True   True
# 2  False  False      False   False  False
# 3  False  False       True   False  False
# 4  False  False      False   False   True
# 5  False  False      False   False   True

# %%
df.isnull().sum()
# Out:
# id           0
# Name         0
# companies    1
# profit       1
# Girls        3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5

# %% [markdown]
# # notnull()

# %%
df.notnull()
# Out:
#      id  Name  companies  profit  Girls
# 0  True  True       True    True   True
# 1  True  True       True   False  False
# 2  True  True       True    True   True
# 3  True  True      False    True   True
# 4  True  True       True    True  False
# 5  True  True       True    True  False

# %%
df.notnull().sum()
# Out:
# id           6
# Name         6
# companies    5
# profit       5
# Girls        3
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 25

# %% [markdown]
# # use series for isnull() and notnull()

# %%
import numpy as np
sr = pd.Series([1,2,3,np.nan, 4, np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
sr.isnull().sum().sum()
# Out:
# 2

# %%
sr.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
sr.notnull().sum()
# Out:
# 4

# %% [markdown]
# # dropna()

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv")
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_values = 'not available')
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df.dropna()
# Out:
#    id     Name   companies profit Girls
# 0   1    Akash  IT service   100%  rima
# 2   3  prakash      health    40%  hema

# %% [markdown]
# # parameters of dropna()

# %% [markdown]
# # axis = 1/0 -------1 means row and 0 means columns

# %%
df.dropna(axis = 1)   # axis me default rhta hai row
# Out:
#    id     Name
# 0   1    Akash
# 1   2    vikas
# 2   3  prakash
# 3   4    sohit
# 4   5   cheems
# 5   6     yash

# %%
df.dropna(axis = 0)
# Out:
#    id     Name   companies profit Girls
# 0   1    Akash  IT service   100%  rima
# 2   3  prakash      health    40%  hema

# %% [markdown]
# # how = 'any'/'all'

# %%
pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_values = 'not available')
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df.dropna(how = 'any')
# Out:
#    id     Name   companies profit Girls
# 0   1    Akash  IT service   100%  rima
# 2   3  prakash      health    40%  hema

# %%
df.dropna(axis = 1, how = 'any')
# Out:
#    id     Name
# 0   1    Akash
# 1   2    vikas
# 2   3  prakash
# 3   4    sohit
# 4   5   cheems
# 5   6     yash

# %%
df.dropna(how = 'all')
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df.dropna(thresh = 1)
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df.dropna(thresh = 5)
# Out:
#    id     Name   companies profit Girls
# 0   1    Akash  IT service   100%  rima
# 2   3  prakash      health    40%  hema

# %%
df.dropna(thresh = 6)
# Out:
# Empty DataFrame
# Columns: [id, Name, companies, profit, Girls]
# Index: []

# %% [markdown]
# # subset()

# %%
df = pd.read_csv("C:\\Users\\kumar\\OneDrive\\Documents\\part8.csv", na_values = 'not available')
df
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df.dropna(subset = ['profit'])
df
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %%
df.dropna(subset = ['Girls'])
df
# Out:
#    id     Name   companies profit  Girls
# 0   1    Akash  IT service   100%   rima
# 1   2    vikas   no values    NaN    NaN
# 2   3  prakash      health    40%   hema
# 3   4    sohit         NaN    46%  gehna
# 4   5   cheems      health    59%    NaN
# 5   6     yash      health    90%    NaN

# %% [markdown]
# # inplace = boolean

# %%
df.dropna(inplace = True)
df
# Out:
#    id     Name   companies profit Girls
# 0   1    Akash  IT service   100%  rima
# 2   3  prakash      health    40%  hema

# %%
df.dropna(inplace = False)
df
# Out:
#    id     Name   companies profit Girls
# 0   1    Akash  IT service   100%  rima
# 2   3  prakash      health    40%  hema
